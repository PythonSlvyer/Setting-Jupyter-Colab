# %% [markdown]
# # **Llama-cpp installation**

# %%
# For Nvidia
# !wget -c https://github.com/ai-dock/llama.cpp-cuda/releases/download/b9467/llama.cpp-b9467-cuda-12.8-amd64.tar.gz
# Out:
# --2026-06-02 08:18:51--  https://github.com/ai-dock/llama.cpp-cuda/releases/download/b9467/llama.cpp-b9467-cuda-12.8-amd64.tar.gz
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# For Cpu/Vulkan
# !wget -c https://github.com/ggml-org/llama.cpp/releases/download/b9469/llama-b9469-bin-ubuntu-vulkan-x64.tar.gz
# Out:
# --2026-06-02 09:47:12--  https://github.com/ggml-org/llama.cpp/releases/download/b9469/llama-b9469-bin-ubuntu-vulkan-x64.tar.gz
# Resolving github.com (github.com)... 20.27.177.113
# Connecting to github.com (github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# For Nvidia
# !tar -xzf llama.cpp-b9467-cuda-12.8-amd64.tar.gz
# Out:
# tar: llamacpp: Not found in archive
# tar: Exiting with failure status due to previous errors

# %%
# For Cpu/Vulkan
# !tar -xzf llama-b9469-bin-ubuntu-vulkan-x64.tar.gz && ls
# Out:
# llama-b9469  llama-b9469-bin-ubuntu-vulkan-x64.tar.gz  sample_data

# %%
# !mv ./llama-b9469/ ./llama-cpp

# %%
ls
# Out:
# llama-b9469-bin-ubuntu-vulkan-x64.tar.gz  llama-cpp/  sample_data/

# %% [markdown]
# # Installing gguf models

# %%
# !wget -c 'https://huggingface.co/unsloth/Qwen3.5-0.8B-MTP-GGUF/resolve/main/Qwen3.5-0.8B-Q4_K_M.gguf' -P ./Models/
# Out:
# --2026-06-02 09:47:34--  https://huggingface.co/unsloth/Qwen3.5-0.8B-MTP-GGUF/resolve/main/Qwen3.5-0.8B-Q4_K_M.gguf
# Resolving huggingface.co (huggingface.co)... 3.165.63.40, 3.165.63.83, 3.165.63.112, ...
# Connecting to huggingface.co (huggingface.co)|3.165.63.40|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
#Configuring Models.ini
# !ls Models
# Out:
# Qwen3.5-0.8B-Q4_K_M.gguf

# %% [markdown]
# # Configuring Models.ini

# %%
# No point in Trying to edit it manually
# > for rewriting >> for appending
# text : temp -> 1 , presence -> 1.5
# %%writefile Models.ini
[Qwen3.5-0.8B]
model             = ./Models/Qwen3.5-0.8B-Q4_K_M.gguf
temperature       = 0.6
top-p			        = 0.95
top-k			        = 20
min-p			        = 0.0
presence-penalty	= 0.0
repeat-penalty 	  = 1.0
flash-attn	 		  = 1
ctx-size          = 32768
# Out:
# Writing Models.ini

# %% [markdown]
# # Running llamacpp
# # Skip this if you want to access it From the Web

# %%
# For Nvidia
! ./cuda-12.8/llama-server --models-preset ./Models.ini
# Out:
# ./cuda-12.8/llama-server: error while loading shared libraries: libcudart.so.12: cannot open shared object file: No such file or directory

# %%
# For CPU/Vulkan
! ./llama-cpp/llama-server --models-preset ./Models.ini --port 8091
# Out:
# 0.00.013.450 I log_info: verbosity = 3 (adjust with the `-lv N` CLI arg)
# 0.00.013.524 I system_info: n_threads = 1 (n_threads_batch = 1) / 2 | CPU : SSE3 = 1 | SSSE3 = 1 | AVX = 1 | AVX2 = 1 | F16C = 1 | FMA = 1 | BMI2 = 1 | LLAMAFILE = 1 | OPENMP = 1 | REPACK = 1 |
# 0.00.013.532 I srv  llama_server: n_parallel is set to auto, using n_parallel = 4 and kv_unified = true
# 0.00.013.625 I srv          init: running without SSL
# 0.00.013.709 I srv          init: using 8 threads for HTTP server
# 0.00.015.528 I srv   load_models: Loaded 0 cached model presets
# 0.00.015.904 I srv   load_models: Loaded 1 custom model presets from ./Models.ini
# 0.00.016.038 I srv    operator(): Available models (1) (*: custom preset)
# 0.00.016.044 I srv    operator():   * Qwen3.5-0.8B
# 0.00.016.223 I srv  llama_server: starting router server, no model will be loaded in this process
# 0.00.016.230 I srv         start: binding port with default address family
# ...

# %% [markdown]
# # **Accessing the Server on The www**
#
#
# *   llama.cpp doesn't dynamically call Models.ini so no point in trying to edit it while running

# %%
# Credit for this Code  : https://www.youtube.com/@AIBrainbox
# In-Video              : https://www.youtube.com/watch?v=ZQFqUdIYgdg
# His Code link         : https://colab.research.google.com/drive/1VFKEy2Ncd_D_ksYDjTrBuQRGvm6Umx3z?usp=sharing Originally for setting Up ComfyUI

# !wget -P ~ https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i ~/cloudflared-linux-amd64.deb

import subprocess
import threading
import time
import socket
import urllib.request

def iframe_thread(port):
  while True:
      time.sleep(0.5)
      sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
      result = sock.connect_ex(('127.0.0.1', port))
      if result == 0:
        break
      sock.close()
  print("\nllama.cpp finished loading, trying to launch cloudflared (if it gets stuck here cloudflared is having issues)\n")

  p = subprocess.Popen(["cloudflared", "tunnel", "--url", "http://127.0.0.1:{}".format(port)], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
  for line in p.stderr:
    l = line.decode()
    if "trycloudflare.com " in l:
      print("This is the URL to access llama.cpp:", l[l.find("http"):], end='')
    #print(l, end='')


threading.Thread(target=iframe_thread, daemon=True, args=(8091,)).start()

#Run Whatever server here
#!python main.py --dont-print-server
! ./llama-cpp/llama-server --models-preset ./Models.ini --port 8091
# Out:
# --2026-06-02 09:48:36--  https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# Resolving github.com (github.com)... 20.27.177.113
# Connecting to github.com (github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/cloudflare/cloudflared/releases/download/2026.5.2/cloudflared-linux-amd64.deb [following]
# --2026-06-02 09:48:36--  https://github.com/cloudflare/cloudflared/releases/download/2026.5.2/cloudflared-linux-amd64.deb
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...
